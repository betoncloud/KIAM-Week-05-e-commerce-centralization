# %% [markdown]
# # EthioMart Centralized E-Commerce

# %% [markdown]
# #### EthioMart plans to create a single centralized platform that consolidates real-time data from multiple e-commerce Telegram channels into one unified channel.This script is to go over the data ingestion and pipelining steps of building a centralized e-commerce channel from various telegram channels for business.

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging
import warnings
from dotenv import load_dotenv
warnings.filterwarnings('ignore')

# Add the parent directory to the Python path
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))




# Load environment variables from .env file
load_dotenv()

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ## Task 1: Data Ingestion and  Data Preprocessing

# %%
from telethon import TelegramClient
from telethon.sessions import MemorySession
import csv
import asyncio
import nest_asyncio  # For environments like Jupyter notebooks

# Apply the patch for nested event loops (useful in Jupyter or nested environments)
nest_asyncio.apply()


api_id = os.getenv("api_id")
api_hash =  os.getenv("api_hash")
phone_number = os.getenv("phone_number")

# List of target Telegram channels
channels = ['@ZemenExpress','@nevacomputer','@meneshayeofficial','@ethio_brand_collection','@Leyueqa','@sinayelj','@Shewabrand','@helloomarketethiopia',
'@modernshoppingcenter','@qnashcom','@Fashiontera','@kuruwear','@gebeyaadama','@MerttEka','@forfreemarket','@classybrands','@marakibrand',
'@aradabrand2','@marakisat2','@belaclassic','@AwasMart','@qnashcom']
# Use MemorySession to avoid SQLite locking issues, replace with string for persistent sessions
client = TelegramClient(MemorySession(), api_id, api_hash)

# File to save the results
output_file = "result.csv"

# Initialize the CSV file with headers if it doesn't exist
def initialize_csv():
    try:
        with open(output_file, mode='x', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(["Channel Name", "Message Date", "Message Content"])
    except FileExistsError:
        pass  # File already exists, no need to overwrite

async def fetch_channel_messages(limit=20):
    """
    Fetch and save messages from specified Telegram channels.
    :param limit: Number of messages to fetch per channel
    """
    with open(output_file, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        for channel in channels:
            try:
                # Get the channel entity
                entity = await client.get_entity(channel)
                print(f"Fetching messages from channel: {entity.title}")
                
                # Fetch the most recent messages
                messages = await client.get_messages(entity, limit=limit)
                for message in messages:
                    if message.text:  # Only process messages with text
                        writer.writerow([entity.title, message.date, message.text])
                        print(f"[{entity.title}] {message.date}: {message.text}")
            except Exception as e:
                print(f"Error fetching messages from {channel}: {e}")

async def main():
    """
    Main function to start the Telegram client, log in, and fetch messages.
    """
    try:
        # Start the client and log in using the phone number
        print("Logging into Telegram...")
        await client.start(phone=phone_number)
        print("Successfully logged in!")
        
        # Fetch messages from the channels
        await fetch_channel_messages(limit=20)
    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        # Ensure the client disconnects cleanly
        print("Disconnecting Telegram client...")
        await client.disconnect()
        print("Client disconnected.")

# Initialize the CSV file
initialize_csv()

# Run the main function in the event loop
if __name__ == "__main__":
    asyncio.run(main())
# Out:
# 2025-01-18 10:15:31,471 - INFO - Connecting to 149.154.167.51:443/TcpFull...
# Logging into Telegram...
# 2025-01-18 10:15:32,903 - INFO - Connection to 149.154.167.51:443/TcpFull complete!
# 2025-01-18 10:15:33,610 - INFO - Phone migrated to 4
# 2025-01-18 10:15:33,759 - INFO - Reconnecting to new data center 4
# 2025-01-18 10:15:33,759 - INFO - Disconnecting from 149.154.167.51:443/TcpFull...
# 2025-01-18 10:15:33,760 - INFO - Disconnection from 149.154.167.51:443/TcpFull complete!
# 2025-01-18 10:15:33,761 - INFO - Connecting to 149.154.167.91:443/TcpFull...
# 2025-01-18 10:15:35,480 - INFO - Connection to 149.154.167.91:443/TcpFull complete!
# Signed in successfully as Bethelhem Teka; remember to not break the ToS or you will risk an account ban!
# Successfully logged in!
# Fetching messages from channel: Zemen Express®
# [Zemen Express®] 2025-01-18 05:12:07+00:00: 💥💥...................................💥💥
#
# 📌Door Bottom Seal Strip Stopper
# 👍በበርዎ ስር አቧራ እና ነፍሳት እንዳይገባ
#     የሚከላከል!!!
# 💯 High Quality
# ®️ አንደኛው ወፍራሙ
#
# 🔰Keep Hot and Cold Air isolated
# 🔰 Reduce The Noise Outside and Door slamming
# 🔰 No 🦟 🪰 🐀 🪳🕷️🐛🦗
#
#
#  ዋጋ፦  💵🏷  400ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-18 05:11:55+00:00: 💥💥...................................💥💥
#
# 📌Door Bottom Seal Strip Stopper
# 👍በበርዎ ስር አቧራ እና ነፍሳት እንዳይገባ
#     የሚከላከል!!!
# 💯 High Quality
# ®️ አንደኛው ወፍራሙ
#
# 🔰Keep Hot and Cold Air isolated
# 🔰 Reduce The Noise Outside and Door slamming
# 🔰 No 🦟 🪰 🐀 🪳🕷️🐛🦗
#
#
#  ዋጋ፦  💵🏷  400ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-18 05:11:36+00:00: 💥💥...................................💥💥
#
# 📌Door Bottom Seal Strip Stopper
# 👍በበርዎ ስር አቧራ እና ነፍሳት እንዳይገባ
#     የሚከላከል!!!
# 💯 High Quality
# ®️ አንደኛው ወፍራሙ
#
# 🔰Keep Hot and Cold Air isolated
# 🔰 Reduce The Noise Outside and Door slamming
# 🔰 No 🦟 🪰 🐀 🪳🕷️🐛🦗
#
#
#  ዋጋ፦  💵🏷  400ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 18:02:23+00:00: 💥💥...................................💥💥
#
# 📌 High pressure water Gun nozzle
#
#    👍መኪና ለማጠብ
#    👍ግቢ ለማፅዳት ተመራጭ
#    👍የራሱ መለዋወጫ ያለው
#
# ዋጋ፦  💵🏷  800 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 18:02:11+00:00: 💥💥...................................💥💥
#
# 📌 High pressure water Gun nozzle
#
#    👍መኪና ለማጠብ
#    👍ግቢ ለማፅዳት ተመራጭ
#    👍የራሱ መለዋወጫ ያለው
#
# ዋጋ፦  💵🏷  800 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 18:02:01+00:00: 💥💥...................................💥💥
#
# 📌 High pressure water Gun nozzle
#
#    👍መኪና ለማጠብ
#    👍ግቢ ለማፅዳት ተመራጭ
#    👍የራሱ መለዋወጫ ያለው
#
# ዋጋ፦  💵🏷  800 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 11:14:54+00:00: 💥💥...................................💥💥
#
# 🎯Electric Hair Steamer Cap
#          💯 High Quality
#
# 🔰የፀጉር እስቲመር ትሪትመንት ወይም ቅቤ ተቀብተው በቤቶ ሆነው የሚጠቀሙበት
#
# ዋጋ፦  💲🏷  800 ብር
#
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 11:14:44+00:00: 💥💥...................................💥💥
#
# 🎯Electric Hair Steamer Cap
#          💯 High Quality
#
# 🔰የፀጉር እስቲመር ትሪትመንት ወይም ቅቤ ተቀብተው በቤቶ ሆነው የሚጠቀሙበት
#
# ዋጋ፦  💲🏷  800 ብር
#
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 09:19:54+00:00: 💥💥...............👸................💥💥
#
# 📌Straight Comb Hair stylist
#
# ‼️ምንም አይነት ድምፅ የሌለው ‼️
#
# ሁሉንም አይነት ጸጉር ያለ ልፋት💯 በሙቀት የሚያስውብ
#
# 👍ለተለያዩ የጸጉር አይነቶች ከፍ እና ዝቅ የሚል የሙቀት መቆጣጠሪያ ያለው
#
# 👍ጸጉር ሳይሰባበር በጤናማ ሁኔታ ውብ የሚያደርግልዎ
#
# ዋጋ፦  💲🏷  1200ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 09:19:43+00:00: 💥💥...............👸................💥💥
#
# 📌Straight Comb Hair stylist
#
# ‼️ምንም አይነት ድምፅ የሌለው ‼️
#
# ሁሉንም አይነት ጸጉር ያለ ልፋት💯 በሙቀት የሚያስውብ
#
# 👍ለተለያዩ የጸጉር አይነቶች ከፍ እና ዝቅ የሚል የሙቀት መቆጣጠሪያ ያለው
#
# 👍ጸጉር ሳይሰባበር በጤናማ ሁኔታ ውብ የሚያደርግልዎ
#
# ዋጋ፦  💲🏷  1200ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 09:19:26+00:00: 💥💥...............👸................💥💥
#
# 📌Straight Comb Hair stylist
#
# ‼️ምንም አይነት ድምፅ የሌለው ‼️
#
# ሁሉንም አይነት ጸጉር ያለ ልፋት💯 በሙቀት የሚያስውብ
#
# 👍ለተለያዩ የጸጉር አይነቶች ከፍ እና ዝቅ የሚል የሙቀት መቆጣጠሪያ ያለው
#
# 👍ጸጉር ሳይሰባበር በጤናማ ሁኔታ ውብ የሚያደርግልዎ
#
# ዋጋ፦  💲🏷  1200ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 05:06:37+00:00: 💥💥...................................💥💥
#
# 🎯 Baby Feeding Bottle Spoon with Container Baby Food Feeder
#       💯 High Quality
#
# 🍼የህፃናት መመገቢያ ጡጦ
#
# 👍Silicone Squeeze Spoon Feeder for Infant Food Dispensing and Feeding
#
# 👍Safe Material
# 👍Filterable Food
# 👍Strong Sealing
# 👍Easy to Use
#
# ዋጋ፦  💵🏷  400 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-17 05:06:27+00:00: 💥💥...................................💥💥
#
# 🎯 Baby Feeding Bottle Spoon with Container Baby Food Feeder
#       💯 High Quality
#
# 🍼የህፃናት መመገቢያ ጡጦ
#
# 👍Silicone Squeeze Spoon Feeder for Infant Food Dispensing and Feeding
#
# 👍Safe Material
# 👍Filterable Food
# 👍Strong Sealing
# 👍Easy to Use
#
# ዋጋ፦  💵🏷  400 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-16 12:49:25+00:00: 💥💥...................................💥💥
#
# 📌 Replacement Silicon Nipple
#
#   👍የጡት ጫፍ
#
# ዋጋ፦  💲🏷  400 ብር
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# [Zemen Express®] 2025-01-16 06:29:40+00:00: 💥💥...................................💥💥
#
# 📌 2in1 Glass oil Sprayer and Dispenser
#
# 👍 ከመቀነሻ በተጨማሪ እንደ ስፕሬይ የሚያገለግል
#
# ዋጋ፦  💲🏷 1100 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Fetching messages from channel: NEVA COMPUTER®
# [NEVA COMPUTER®] 2024-12-07 06:55:36+00:00: **Very portable and can do multi-task
# **
# **#HP**** ELITEBOOK 1040 G6**
# 🅑︎🅡︎🅐︎🅝︎🅓︎ :** HP **ELITEBOOK
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: **14” convertable touch screen **full HD
# ✨🅒︎🅟︎🅤︎: CORE I7 8th generation
# ✨🅡︎🅐︎🅜︎:16 GB 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512 GB SSD
# ✨🅖︎raphics: intel uhd graphics
# ✨🅞︎🅢︎:window 11 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 5HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  open box
# Price  👇
# 📩@rasneva ለአጭር መልእክት
#  ይደዉሉ ☎️
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
#
# ድህረ ገጻችንን ይጎብኙ
# www.nevacomputer.com
#
# ቴሌግራም ቻናላችንን ይቀላቀሉ
#
# https://t.me/nevacomputer
# [NEVA COMPUTER®] 2024-12-07 06:55:13+00:00: **Very portable and can do multi-task
# **
# **#HP**
# 🅑︎🅡︎🅐︎🅝︎🅓︎ :** HP **ELITEBOOK
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎:14”
# ✨🅒︎🅟︎🅤︎: CORE I7 8th generation
# ✨🅡︎🅐︎🅜︎:16 GB 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512 GB SSD
# ✨🅖︎raphics: intel uhd graphics
# ✨🅞︎🅢︎:window 11 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 5HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  open box
# Price  👇
# 📩@rasneva ለአጭር መልእክት
#  ይደዉሉ ☎️
#
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
#
# ድህረ ገጻችንን ይጎብኙ
# www.nevacomputer.com
#
# ቴሌግራም ቻናላችንን ይቀላቀሉ
#
# https://t.me/nevacomputer
# [NEVA COMPUTER®] 2024-12-07 06:52:27+00:00: **#hp**** **Elitebook **
# ****#EUROPE**** STANDARD **
# 🅑︎🅡︎🅐︎🅝︎🅓︎ : hp Elitebook TOUCH SCREEN
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: **14” ultra slim TOUCH SCREEN **
# ✨🅒︎🅟︎🅤︎: core i7 10th generation
# ✨🅡︎🅐︎🅜︎:16GB 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512GB SSD
# ✨🅖︎🅡︎🅐︎🅟︎🅗︎🅘︎🅒︎🅢︎: Intel Iris graphics card
# ✨🅞︎🅢︎:window 10 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎:7hr
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  brand new
# Price 👇
# 📩@rasneva ለአጭር መልእክት
#
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
# [NEVA COMPUTER®] 2024-12-07 06:33:16+00:00: 🔤🔤🔤🅰️
# 🔤🔤🔤🔤🔤🔤🔤🔤
# **
# ****#9th**** generation **workstation laptop ✔️**
# ****#USA**** STANDARD **
# 🅑︎🅡︎🅐︎🅝︎🅓︎ :** LENOVO thinkpad p50**
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: **15.6” 4k screen **
# ✨🅒︎🅟︎🅤︎: CORE I7 9th gen❤️  12 cpu
# ✨🅡︎🅐︎🅜︎:16GB 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512 GB SSD
# ✨🅖︎🅡︎🅐︎🅟︎🅗︎🅘︎🅒︎🅢︎: 4GB NIVIDIA QUADRO T2000
# ✨🅞︎🅢︎:𝘄𝗶𝗻𝗱𝗼𝘄𝘀 11 pro 22H2
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 6HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎: openbox
# Price
# 📩@rasneva ለአጭር መልእክት
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
#
# ድህረ ገጻችንን ይጎብኙ
# www.nevacomputer.com
#
# ቴሌግራም ቻናላችንን ይቀላቀሉ
#
# https://t.me/nevacomputer
#
#      🔠🔠🔠🅰️ 🔠🔠🔠🔠🔠🔠🔠🔠
# [NEVA COMPUTER®] 2024-12-07 06:31:12+00:00: **#HP**** PAVILION**
# 🅑︎🅡︎🅐︎🅝︎🅓︎ :** HP PAVILION **X360
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: **14” FHD TOUCH SCREEN **CONVERTIBLE** **
# ✨🅒︎🅟︎🅤︎: CORE I5 11th GEN 💪🏽
# ✨🅡︎🅐︎🅜︎:16Gb 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512GB SSD
# ✨🅖︎🅡︎🅐︎🅟︎🅗︎🅘︎🅒︎🅢︎: INTEL IRIS XE GRAPHICS
# ✨🅞︎🅢︎:window 10 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 6HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  brand new
# 📩@rasneva ለአጭር መልእክት
#
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
# [NEVA COMPUTER®] 2024-12-07 06:28:23+00:00: **🔥2022 BRAND NEW🔥🔥🔥
# 🅑︎🅡︎🅐︎🅝︎🅓︎ : LENOVO LOQ
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 2K **RESOLUTION**
# ✨🅒︎🅟︎🅤︎:RYZEN 7 7000 serious
# ✨🅡︎🅐︎🅜︎:16GB 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512 SSD
# ✨🅖︎🅡︎🅐︎🅟︎🅗︎🅘︎🅒︎🅢︎: RTX 4050 4GB DEDICATED
# ✨🅞︎🅢︎:𝘄𝗶𝗻𝗱𝗼𝘄𝘀 11 pro 22H2
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 6HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎: BRAND NEW **
# CONTACT @rasneva
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
# Fetching messages from channel: መነሻዬ
# [መነሻዬ] 2025-01-16 08:37:07+00:00: ተወዳጇ ሚስ ተወዳጁን የሂሳብ ሊቅ ጥቅልን ለማስማሪያነት ተጠቅማለች
# ቁጥር በቀላሉ ከመለየት ጀምራለች
# መደመር ፣ መቀነስ ፣ ማካፈል ፣ ማባዛት እያለማመደች
# የተማሪዎቿን የሂሳብ መነሻ አቅልላለች
# የነገ የሂሳብ ሊቅ እንደሚሆኑ እርግጠኛ ነች
#
# እርሶም ይህን ጥቅል ከመነሻዬ ይግዙ
# የልጆዎን የሂሳብ መነሻ ያቅልሉ
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
#
# አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር ፤ ፒያሳ ካንትሪ ታወር ፤ ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
# [መነሻዬ] 2025-01-11 07:27:53+00:00: ልጆችዎ ድክ ድክ ብለው ንግግር ይጀምሩ
#
# 🗣ድክዬ ድክዬ. . .ድክ. . .ድክዬ
# ሰምቼ ማልጠግባት ውብ መማሪያዬ
#
#
# 👉የመጀመሪያ ደረጃ ባለድምፅ የልጆች መማሪያ
# በአማርኛ እና በእንግሊዘኛ ቋንቋ
#
# 👉ትምህርት ቤት ላልገቡ ቤት ውስጥ ለተቀመጡ ህፃን ተመራጭ
#
# 👉በቻርጅም በባትሪም የሚሰራ ሲሆን ወደተፈለገው ቦታ ይዞ ለመንቀሳቀስ ምቹ።
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
#
# አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር ፤ ፒያሳ ካንትሪ ታወር ፤ ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
# [መነሻዬ] 2025-01-03 07:28:40+00:00: **የቀለሜ መነሻ ጥቅል
# ልጆች እየወደዱ የሚማሩበት ፤ ሳይሰላቹ የሚያጠኑበት!!**
#
# የቀለሜ መነሻ ጥቅል
#
# 👉ከእርሳስ አያያዝ ችሎታ ጀምሮ ልጆችን ማንበብ ፣ መፃፍ ፣ ማዳመጥ እና ማንበብ  ችሎታቸውን በተቀናጀ መልኩ በምስል ፣ በድምፅና በተግባር የሚለማመዱበት አስደናቂ ጥቅል
#
#
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
#
# አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር ፤ ፒያሳ ካንትሪ ታወር ፤ ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
#
#
# #meneshaye #መነሻዬ #kidsmaths #kids #success #focus #children #education  #science #knowledge #math #maths #mathematics #concentration   #primaryeducation  #braindevelopment #kidsimagination
# [መነሻዬ] 2025-01-02 09:26:08+00:00: እነዚህን ሁሉ በአንድ ላይ የገና ስጦታ
#
# ለመሸለም
# 1.  @gelagle_   tik tok account መቀላቀል
# 3.ለ አምስት ሰው ማጋራት
# 2.ላይክ እና ኮሜንት ላይ   @ gelagle_  ብለው ሜንሽን በማድረግ ፣ ለእናታችሁ ፍቅራችሁን መግለጽ እና ብዙ ላይክ ያገኘ ተሸላሚ ይሆናል
#
# https://t.me/gelaglewoch ቴሌግራም ቻናል ይቀላቀሉን
# [መነሻዬ] 2025-01-01 12:12:51+00:00: የገና ስጦታ🎁🎁🎁
# ለመሸለም
# 1.  @gelagle  tik tok account መቀላቀል
# 2.ለ አምስት ሰው ማጋራት
# 3.ኮሜንት ላይ @gelagle ብለው ሜንሽን በማድረግ ፣ ለእናታችሁ ፍቅራችሁን በ ኮሜንት ላይ በመግለጽ እና ብዙ ላይክ ያገኘ ተሸላሚ ይሆናል
# [መነሻዬ] 2025-01-01 07:20:12+00:00: እንኳን ለገና በአል በሰላም አደረሳቹ
#
# መነሻዬ!!
# ልጆችዎ የማንበብ ፣ መፃፍ ፣ ማዳመጥ እና ማንበብ  ችሎታቸውን በተቀናጀ መልኩ በምስል ፣ በድምፅና በተግባር የሚለማመዱበትን አስደናቂ ጥቅል ለልጆችዎ #ስጦታ_ይስጡ
#
# መልካም የገና በአል!!
# [መነሻዬ] 2024-12-30 12:46:42+00:00: 🌟**የመነሻዬ ማቅለሚያ ጥቅል**🌟
#      **ይህ ጥቅል ለልጆችዎ
#    ከማቅለምም በላይ ነው!!**
#
# 👉 የልጆችዎን የማቅለም ፍላጎት የሚጨምር
# 👉 ቀለም የማያሳልፍ የማቅለሚያ መፅሀፍ
# 👉 መጥፋት የሚችሉ **12** ማርከሮች
# 👉 የልጆችን ምናብ የሚያሳድጉ ንድፎች
# 👉 ከ **40** በላይ ገፆች
# 👉 ልጆች እንዲስሉ የሚያደርጉ ጣፋጭ ታሪኮች
# 👉 የምስክር ወረቀት
#
# ዋጋ 1400
#
# የማህበራዊ ድረገፆቻችንን ይጎብኙ
# https://linktr.ee/meneshaye
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# **አድራሻ**፦ 1.ጉርድ ሾላ ሆሊ ሲቲ ሴንተር
#                2. ፒያሳ ካንትሪ ታወር
# በተጨማሪም 👉 ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
# #መነሻዬ #meneshaye #kidscoloring #coloring #drawing #sketching #art #kidsdrawing #painting #imagination #globalart #funart #creativearts #coloringpage #happykids #kidsactivity #illustration #coloringbook #coloringpages #creativity #dailyaffirmations #coloringtherapy #
# [መነሻዬ] 2024-12-27 06:29:22+00:00: ልጆችዎ ድክ ድክ ብለው ንግግር ይጀምሩ
#
# 🗣ድክዬ ድክዬ. . .ድክ. . .ድክዬ
# ሰምቼ ማልጠግባት ውብ መማሪያዬ
#
#
# 👉የመጀመሪያ ደረጃ ባለድምፅ የልጆች መማሪያ
# በአማርኛ እና በእንግሊዘኛ ቋንቋ
#
# 👉ትምህርት ቤት ላልገቡ ቤት ውስጥ ለተቀመጡ ህፃን ተመራጭ
#
# 👉በቻርጅም በባትሪም የሚሰራ ሲሆን ወደተፈለገው ቦታ ይዞ ለመንቀሳቀስ ምቹ።
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
#
# አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር ፤ ፒያሳ ካንትሪ ታወር ፤ ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
# [መነሻዬ] 2024-12-26 12:34:29+00:00: ተወዳጇ ሚስ በተወዳጁ መነሻዬ ሙዚቃ
#
# የቀለሜ መነሻ ጥቅል በልጆች ዘንድ ተወዳጅ ሆኗል  በቤት ውስጥም ምርጥ መማሪያ ሆኗል።
# [መነሻዬ] 2024-12-24 09:50:54+00:00: ለልጆችዎ ትምህርትና ጨዋታ
# ዘመን ተሻጋሪ ስጦታ
#
# #መነሻዬ_ታብሌት_ጥቅል
#
# አድራሻ ፦
# 1 .ጉርድ ሾላ ሆሊ ሲቲ ሴንተር 3ኛ ፎቅ
# 2 . ፒያሳ ካንትሪ ታወር 2ኛ ፎቅ፤
# 3 . ጀሞ ደሊና ህንፃ ምድር ላይ
# (ከኦልማርት ጎን)
# 4 . ገርጂ መብራት ሃይል
#       ፋውንቴን ህንፃ 1ኛ ፎቅ
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
# #Tablet #Meneshaye_Tablet #kids_tablet #uniqe_tablet #latest_version_kids_tablet #iwawa #portableblender  #kids_store #shewit #educationaltoys #meneshaye #meneshayestore
# [መነሻዬ] 2024-12-23 13:03:25+00:00: Cheers ለልጆቻችን ስንል ደፋ ቀና ለምንል ወላጆች
#
# የልጆዎን መነሻ ያቅልሉ
# 0911259661 / 0989939393
# #fyp,#habesha,#learning,#ethiopia
# [መነሻዬ] 2024-12-21 11:58:55+00:00: መነሻዬ ድክድክ
#
# 👉የመጀመሪያ ደረጃ ባለድምፅ የልጆች መማሪያ
# በአማርኛ እና በእንግሊዘኛ ቋንቋ
#
# 👉ትምህርት ቤት ላልገቡ ቤት ውስጥ ለተቀመጡ ህፃን ተመራጭ
#
# 👉በቻርጅም በባትሪም የሚሰራ ሲሆን ወደተፈለገው ቦታ ይዞ ለመንቀሳቀስ ምቹ።
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
#
# አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር ፤ ፒያሳ ካንትሪ ታወር ፤ ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
#
# 🗣 በ እረፍት ቀን ለሚገበያዩ ደንበኞቻችን
#
# እሁድ ሙሉ ቀን ከጠዋት 3:00 አስከ ምሽት #1:00 #ጉርድ_ሾላ_ቅርንጫፍ ክፍት መሆኑን እናሳውቃለን!
# [መነሻዬ] 2024-12-20 08:39:57+00:00: ሂሳብ ለልጆች እንደማስተማር የሚያሰለች እና የሚያደክም ነገር የለም! በእርግጠኝነት በዚህ ሃሳብ ብዙ ወላጆች ትስማማላችሁ እና በዚህ video  **የሂሳብ ሊቅ መነሻ !! ምን እንደሆነ በርግጠኝነት ትረዳላቹ**
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
#
# አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር ፤ ፒያሳ ካንትሪ ታወር ፤ ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
# [መነሻዬ] 2024-12-19 08:45:35+00:00: የቀለሜ መነሻ ጥቅል
#
# 👉ከእርሳስ አያያዝ ችሎታ ጀምሮ ልጆችን ማንበብ ፣ መፃፍ ፣ ማዳመጥ እና ማንበብ  ችሎታቸውን በተቀናጀ መልኩ በምስል ፣ በድምፅና በተግባር የሚለማመዱበት አስደናቂ ጥቅል
#
# 👉በአማርኛ እና በእንግሊዘኛ ቋንቋ የተዘጋጀ
# 👉የልጆችን መማር ፍላጎት የሚያነሳሱ 68 መማሪያዎችን ግልፅ ከሆነ አጠቃቀም መመሪያ ጋር የያዘ
#
#
# 👉ደጋግመው የሚጠቀሙባቸው 11 መፃህፍት
# 👉 ባለ ድምፅ መማሪያ መነሻዬ ፓድ
# 👉 2 በ1 ሰሌዳ
# 👉 ኤሌክትሮኒክ ሰሌዳ
# 👉 የሰዓት መማሪያ ቦርድ
# 👉ከ20 በላይ ማርከሮችና ጠመኔዎች
# 👉 በዶ/ር ኢዮብ ማሞ ተዘጋጅቱ ለወላጆች ከመነሻዬ ከተበረከተ ስጦታ ጋር
#
# ዋጋ 12000
#
#
# የማህበራዊ ድረገፆቻችንን ይጎብኙ
# https://linktr.ee/meneshaye
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# **አድራሻ**፦ 1.ጉርድ ሾላ ሆሊ ሲቲ ሴንተር
#                2. ፒያሳ ካንትሪ ታወር
# በተጨማሪም 👉 ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
#
# #meneshaye #መነሻዬ #kidsmaths #kids #success #focus #children #education  #science #knowledge #math #maths #mathematics #concentration   #primaryeducation  #braindevelopment #kidsimagination
# [መነሻዬ] 2024-12-17 10:03:42+00:00: 🗣ድክዬ ድክዬ. . .ድክ. . .ድክዬ
# ሰምቼ ማልጠግባት ውብ መማሪያዬ
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# http://tiktok.com/@meneshayeofficial
#
#
# አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር ፤ ፒያሳ ካንትሪ ታወር ፤ ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
# [መነሻዬ] 2024-12-16 07:37:16+00:00: የቀለሜ መነሻ ጥቅል
#
# 👉ከእርሳስ አያያዝ ችሎታ ጀምሮ ልጆችን ማንበብ ፣ መፃፍ ፣ ማዳመጥ እና ማንበብ  ችሎታቸውን በተቀናጀ መልኩ በምስል ፣ በድምፅና በተግባር የሚለማመዱበት አስደናቂ ጥቅል
#
# 👉በአማርኛ እና በእንግሊዘኛ ቋንቋ የተዘጋጀ
# 👉የልጆችን መማር ፍላጎት የሚያነሳሱ 68 መማሪያዎችን ግልፅ ከሆነ አጠቃቀም መመሪያ ጋር የያዘ
#
#
# 👉ደጋግመው የሚጠቀሙባቸው 11 መፃህፍት
# 👉 ባለ ድምፅ መማሪያ መነሻዬ ፓድ
# 👉 2 በ1 ሰሌዳ
# 👉 ኤሌክትሮኒክ ሰሌዳ
# 👉 የሰዓት መማሪያ ቦርድ
# 👉ከ20 በላይ ማርከሮችና ጠመኔዎች
# 👉 በዶ/ር ኢዮብ ማሞ ተዘጋጅቱ ለወላጆች ከመነሻዬ ከተበረከተ ስጦታ ጋር
#
# ዋጋ 12000
#
#
# የማህበራዊ ድረገፆቻችንን ይጎብኙ
# https://linktr.ee/meneshaye
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# **አድራሻ**፦ 1.ጉርድ ሾላ ሆሊ ሲቲ ሴንተር
#                2. ፒያሳ ካንትሪ ታወር
# በተጨማሪም 👉 ጀሞ ደሊና ሞል ፤ ገርጂ ከፋውንቴን ህንፃ ፊት ለፊት
#
# #meneshaye #መነሻዬ #kidsmaths #kids #success #focus #children #education  #science #knowledge #math #maths #mathematics #concentration   #primaryeducation  #braindevelopment #kidsimagination
# Fetching messages from channel: EthioBrand®
# [EthioBrand®] 2025-01-18 07:00:06+00:00: Under armour sonic 5
# Size 40,41,42,43
# Price 3300 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-17 12:28:04+00:00: Under armour Goretex
# Size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-17 10:05:50+00:00: 🥳ለጥምቀት እንዲሁም ለተለያዩ በዓላት ወይም ፕሮግራም የሚሆኑ ፥
#
# White Sandals
# Size 40,41,42,43,44
# Price 1900 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-17 06:25:06+00:00: Nike Air Force Goretex
# Size 40,41,42,43
# Price 3800 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-16 09:04:25+00:00: Nike air zoom pegasus running
# Size 40,41,42,43
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-16 06:00:06+00:00: Adidas terrex running
# size 41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-15 09:04:39+00:00: Skechers Quantum flex
# size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-15 06:23:40+00:00: Nike Air Force olive canvas
# size 40,41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-14 17:05:31+00:00: 🥳ለጥምቀት እንዲሁም ለተለያዩ በዓላት ወይም ፕሮግራም የሚሆኑ ፥
#
# White Sandals
# Size 40,41,42,43,44
# Price 1900 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-14 07:23:42+00:00: Adidas ADI2000
# Size 40,41,42,43,44
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-13 07:15:06+00:00: Adidas Campus
# Size 40,41,42,43
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-12 07:05:06+00:00: ‼️ እሁድ ሁሌም ክፍት ነን ‼️
#
# Nike Air Force Lux
# Size 40,41,42,43,44
# Price 3300 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-11 10:09:39+00:00: Under armour Goretex
# Size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-11 07:12:19+00:00: Nike relentless 7
# size 40,41,42,43
# Price 3200birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-10 10:13:45+00:00: Puma beige SD
# Size 40,41,42,43
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-10 06:21:52+00:00: Adidas duramo speed
# Size 40,41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-09 10:02:48+00:00: Nike Air Force blanco
# Size 40,41,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-09 07:08:09+00:00: Nike air zoom pegasus running
# Size 40,41,42
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-08 10:00:44+00:00: Jordan retro 4
# Size 39,40,41,42,43
# Price 3300 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# [EthioBrand®] 2025-01-08 07:00:54+00:00: Nike Air Force PRM 07
# Size 39,40,41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Fetching messages from channel: ልዩ እቃ
# [ልዩ እቃ] 2025-01-18 06:31:28+00:00: ❗️❗️⁉️ልጆች እንዳይጠፉ **2M Anti Lost Wrist Link Belt Anti Lost Wrist Link Toddler 360 Rotate Security Baby Toddler Reins Child Anti-Lost Wrist Strap with Key Lock Toddler**
# ✔️450 ብር
# ክፍያዎን_በሞባይል_ባንኪንግ_መፈፀምም_ይችላሉ በተጨማሪ #ከ_1000_ብር በላይ የሆኑ
# #ሁለት_ዕቃዎች ሲገዙ ስጦታ እንልክለዎታለን 🛍
# ⚠️⚠️ T.me/Leyueqa ⚡️ቻናላችንን ለጓደኛዎ ሸር ማድረግዎን አይርሱ
#          📌📌📌አድራሻ👀
# ⭕️ቁጥር 1 ልደታ ወደ ባልቻ ሆስፒታል ገባ ብሎ  አህመድ ህንፃ ላይ 1ኛፎቅ 105B
# ⭕️ቁጥር 2 __ 22 አውራሪስ ሆቴል አጠገብ  በፀጋ ህንፃ 3ኛ ፎ ቅ ከ ሊፍቱ  በ ግራ የሱቅ ቁጥር👌 C10
# ይደዉሉልን👆
#
#
# 0933334444 @LeMazez_z
# 0946242424 @Le_Mazez
# 0944109295 @Lemaze_z
# [ልዩ እቃ] 2025-01-18 06:12:28+00:00: 📣🔴Door Step Shoe Rack
#
# ✔️ የበር ስር ጫማ ማስቀመጫ
# ✔️  የብረት ቱቦ
# ✔️ 18 ጥንድ ጫማዎችን የሚያስቀምጡበት
# ✔️ 55cm*26cm*1.14M ስፋት ያለው
# ✔️ ባለ 6 ደረጃ
# ✔️ ደረጃዎቹ የብረት ናቸው
# ✔️ በቀላሉ የሚገጣጥሙት
#
# 💸💸2600 ✔️ዲሊቨሪ አናስከፍልም🚫
#
# #ክፍያዎን_ ዕቃዉ _እጅዎ ሲደርስ_ከፈለጉ_በካሽ_አልያም_በሞባይል_ባንኪንግ_መፈፀም_ይችላሉ በተጨማሪ #ከ_1000_ብር በላይ የሚተመኑ #ሁለት_ዕቃዎችን_ ሲገዙ ስጦታ እንልክለዎታለን
# 🎁 T.me/Leyueqa 👈ቻናላችንን ለጓደኛዎ ሸር ማድረግዎን አይርሱ
#            👉 ያሉበት ድረስ በነፃ እናደርሳለን 🚗
#
#             0933334444 @LeMazez_z
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
# [ልዩ እቃ] 2025-01-17 11:40:35+00:00: ⬇️⬇️⬇️9pcs Kitchen knife Set
#
# ✔️1 ሞረድ
#
# ✔️4 በተለያየ መጠን ቢላዎች
#
# ✔️1 መቀስ
#
# ✔️1 መከትከቻ
#
# ✔️ከማስቀመጫው ጋር
#
#
#        ዋጋ 👉 ✔️2,700 ብር
#
#
# ባሉበት  ያለተጨማሪ ክፍያ ማዘዝ ይችላሉ
# 0933334444 @LeMazez_z
# 0946242424 @Le_Mazez
# 0944109295 @Lemaze_z
# [ልዩ እቃ] 2025-01-17 06:02:21+00:00: 🔥💥Spark electronic gas lighter
#
# Price⚡️ 750
#   🎁 T.me/Leyueqa 👈ቻናላችንን ለጓደኛዎ ሸር ማድረግዎን አይርሱ
#
#             0933334444 @LeMazez_z
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
# [ልዩ እቃ] 2025-01-16 13:18:01+00:00: 👍👍👍👍
#
# 📣 Kitchen Expert 3 in 1 Chopper and Garlic Peeler
#
# ✔️ 3 ሊትር የሚይዙ ሁለት ቋቶች
# ✔️ አንዱ የብረት አንዱ ደግሞ ወፍራም ጠርሙስ
# ✔️ ባለ 4 ምላጭ እና ባለ 2 ምላጭ መፍጪያ ያለው
# 👀 ስጋ፣ ጨጓራ፣ አትክልት፣ ቀይ ሽንኩርት፣ነጭ ሽንኩርት ይፈጩበታል👀
# 🔔 የደረቀ እና የተፈለፈለ ነጭ ሽንኩርት ገለባ  መላጪያ ያለው🔔
# 📌 ተጨማሪ አንድ መቀየሪያ ባለ 4 ምላጭ ያለው
# ✔️ባለ 3 ፕሬስ መፍጪያ
#
# ዋጋ 👍3700
#
# ከነፃ ዲሊቨሪ ጋር
# #ክፍያዎን_በሞባይል_ባንኪንግ_መፈፀምም_ይችላሉ በተጨማሪ #ከ_1000_ብር በላይ የሆኑ #ሁለት_ዕቃዎች ሲገዙ ስጦታ እንልክለዎታለን
# 🎁 T.me/Leyueqa 👈ቻናላችንን ለጓደኛዎ ሸር ማድረግዎን አይርሱ
#             0911236983 @Leyustore
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
# [ልዩ እቃ] 2025-01-16 10:08:01+00:00: 🔥🔥🔥2 ድስቶች + 1 ወጥ ማቅረቢያ + 1 መጥበሻ
#   የማይዙ የማያሳርሩ ለይታ ውቡ የሆኑ
#          ዋጋ 💵6500 ብር  🛞🛞ከነፃ ዲሊቨሪ ጋር🛞🛞
#
#      0911236983 @Leyustore
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
# [ልዩ እቃ] 2025-01-16 08:31:59+00:00: 🔠🔠🔠🔠 🔠🔠🔠🔠🔠🔠5-in-1 Trouser Hanger የሱሪ ማስቀመጫ
# ✔️ የሱሪ ማስቀመጫ ሱሪዎ ወይም ልብስዎ ባለበት ንፅህናው እንደተጠበቀ ሳይጨማደድ ለማስቀመጥ ተመራጭ
# ✔️Size:34cmx32cmx6.5cm
#  ዋጋ፦ ✔️850 ብር
#
# ⭐️2 እና ከዚያ በላይ ነፃ ዲሊቨሪ⭐️
#
#            0911236983 @Leyustore
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
# [ልዩ እቃ] 2025-01-16 06:06:28+00:00: 🆕🆕🆕3 Partitioned Nonstick Omlett, Egg Maker Pan
#
# 📌🔼 3 ክፍል ያለዉ የኦምሌት, የእንቁላል እና የበርገር መጥበሻ
#
# 🧳 የማይዝ
#
# ⬇️ቁርስዎን ቀለል ባለ መንገድ ለማዘጋጀት
#
# ዋጋ  ✔️1250 ከነፃ ዲሊቨሪ ጋር
#
# ከነፃ ዲሊቨሪ ጋር
# #ክፍያዎን_በሞባይል_ባንኪንግ_መፈፀምም_ይችላሉ በተጨማሪ #ከ_1000_ብር በላይ የሆኑ #ሁለት_ዕቃዎች ሲገዙ ስጦታ እንልክለዎታለን
# 🎁 T.me/Leyueqa 👈ቻናላችንን ለጓደኛዎ ሸር ማድረግዎን አይርሱ
#             0911236983 @Leyustore
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
# [ልዩ እቃ] 2025-01-15 13:48:27+00:00: 🏍🏍🏍🏍🏍🏍🏍🏍 Soybean Milk Machine
#
# ✔️ የአኩሪ አተር ወተት መስሪያ ማሽን
#
# ✔️በራሱ ቀቅሎ ፤ ፈጭቶ ፤ በራሱ የሚያፈላ
#
# ✔️በተጨማሪ ጁስ ለማዘጋጀት የሚሆን
#
# ✔️ በተለይ የህፃናት ምግብ ለማዘጋጀት ተመራጭ
#
# ዋጋ፦ 💰 3500 ብር ✔️
#
# 🚚 ይዘዙን ፤ ያሉበት በነፃ እናደርሳለን!!
#
#
# ከነፃ ዲሊቨሪ ጋር
# #ክፍያዎን_በሞባይል_ባንኪንግ_መፈፀምም_ይችላሉ በተጨማሪ #ከ_1000_ብር በላይ የሆኑ #ሁለት_ዕቃዎች ሲገዙ ስጦታ እንልክለዎታለን
# 🎁 T.me/Leyueqa 👈ቻናላችንን ለጓደኛዎ ሸር ማድረግዎን አይርሱ
#             0911236983 @LeMazez_z
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
# Fetching messages from channel: SINA KIDS/ሲና ኪድስⓇ
# [SINA KIDS/ሲና ኪድስⓇ] 2025-01-18 05:57:12+00:00: ክቡራን ደምበኞቻችን ዛሬ ሁሉም ሱቆቻችን ሙሉ ቀን ክፍት እንደሆኑ ስንገልፅ በታላቅ አክብሮት ነው 🙏  የዴሊቨሪ አገልግሎትም እንሰጣለን
# [SINA KIDS/ሲና ኪድስⓇ] 2025-01-17 18:10:21+00:00: ብዙ አገልግሎቶችን በአንድ የያዘ 5 in 1 ጄሪሎ
# 1⃣ ውስጡ ገብተው እየተጫወቱ እንዲራመዱ ይረዳቸዋል
# 2⃣ቅዝቃዜ እግራቸውን እንዳይጎዳቸው የሚወጠር ጨርቅ ስላለው ጨርቁ ተወጥሮ ጨርቁ ላይ መቆም ይችላሉ
# 3⃣ እንደ ፑሽ ካር እራሳችን እየገፍን እናጫውትበታለን
# 4⃣ እንደ ዎከር ልጁ ከፍ ብሎ እቃ እየያዘ ለመራመድ በሚጥርበት ጊዜም እየነዳው መራመድ ይችላል
# 5⃣ መጫዎቻው አሸንጉሊት ተነስቶም እንደ መመገቢያም ወንበርም መሆን ይችላል
# ✅ የራሱ ጥላ ስላለው ጊቢ ውስጥም መጠቀም ይችላል
# 8500 ብር
# Free delivery
#
# 0909003864
# 0905707448
#
# ሊንኩን በመጫን ቴሌግራማችንን [ይቀላቀሉ](https://t.me/sinayelj)[https://t.me/sinayelj](https://t.me/sinayelj)
#
# እቃ ለማዘዝ ከስር ያለውን ሊንኮች በመጫን ማዘዝ ትችላላቹ
#
# @sinasinaye
#
# [https://t.me/sinayelj2](https://t.me/sinayelj2)
#
# አድራሻ
#
#  1️⃣ቁጥር1 ገርጂ ኢምፔሪያል ከሳሚ ህንፃ ጎን አልፎዝ ፕላዛ ግራውንድ ላይ እንደገቡ ያገኙናል
#
# 2️⃣ቁጥር2 4ኪሎ ቅድስት ስላሴ ህንፃ ማለትም ከብልፅግና ዋናፅፈት ቤት ህንፃ በስተ ቀኝ ባለው አስፓልት 20ሜትር ዝቅ እንዳሉ ሀበሻ ኮፊ የሚገኝበት ቀይ ሸክላ ህንፃ 2ተኛ ፎቅ ላይ ያገኙናል
#
# ክቡራን ደምበኞቻችን ገርጂ አልፎዝ ፕላዛ ላይ አራት ኪሎ ቅድስት ስላሴ ያሉት ሱቆቻችን ሲመጡ  አስተማማኝ ሰፊ ፓርኪንግ ያላቸው መሆናቸውን በታላቅ ደስታ እናበስራለን🙏🙏🙏
# [SINA KIDS/ሲና ኪድስⓇ] 2025-01-15 12:00:45+00:00: Volkswagen design የልጆችን ቀልብ የሚገዛ ውብ ፖፖ
#
# እጀታው መብራት ያለው
#
# 0909003864  0905707448
# 3200 ብር
#
# 0909003864
# 0905707448
#
# ሊንኩን በመጫን ቴሌግራማችንን [ይቀላቀሉ](https://t.me/sinayelj)[https://t.me/sinayelj](https://t.me/sinayelj)
#
# እቃ ለማዘዝ ከስር ያለውን ሊንኮች በመጫን ማዘዝ ትችላላቹ
#
# @sinasinaye
#
# [https://t.me/sinayelj2](https://t.me/sinayelj2)
#
# አድራሻ
#
#  1️⃣ቁጥር1 ገርጂ ኢምፔሪያል ከሳሚ ህንፃ ጎን አልፎዝ ፕላዛ ግራውንድ ላይ እንደገቡ ያገኙናል
#
# 2️⃣ቁጥር2 4ኪሎ ቅድስት ስላሴ ህንፃ ማለትም ከብልፅግና ዋናፅፈት ቤት ህንፃ በስተ ቀኝ ባለው አስፓልት 20ሜትር ዝቅ እንዳሉ ሀበሻ ኮፊ የሚገኝበት ቀይ ሸክላ ህንፃ 2ተኛ ፎቅ ላይ ያገኙናል
#
# ክቡራን ደምበኞቻችን ገርጂ አልፎዝ ፕላዛ ላይ አራት ኪሎ ቅድስት ስላሴ ያሉት ሱቆቻችን ሲመጡ  አስተማማኝ ሰፊ ፓርኪንግ ያላቸው መሆናቸውን በታላቅ ደስታ እናበስራለን🙏🙏🙏
# [SINA KIDS/ሲና ኪድስⓇ] 2025-01-13 09:16:50+00:00: Standing mosquito net
# ለመኝታ ቤት ውበትን አላብሶ የተለያዩ ተባዮችን የሚከላከል
# ውብ አጎበር
#
#
# ለ 1.80 አልጋ ሳይዝ  6500ብር  Free delivery
#
# 0909003864
# 0905707448
#
# ሊንኩን በመጫን ቴሌግራማችንን [ይቀላቀሉ](https://t.me/sinayelj)[https://t.me/sinayelj](https://t.me/sinayelj)
#
# እቃ ለማዘዝ ከስር ያለውን ሊንኮች በመጫን ማዘዝ ትችላላቹ
#
# @sinasinaye
#
# [https://t.me/sinayelj2](https://t.me/sinayelj2)
#
# አድራሻ
#
#  1️⃣ቁጥር1 ገርጂ ኢምፔሪያል ከሳሚ ህንፃ ጎን አልፎዝ ፕላዛ ግራውንድ ላይ እንደገቡ ያገኙናል
#
# 2️⃣ቁጥር2 4ኪሎ ቅድስት ስላሴ ህንፃ ማለትም ከብልፅግና ዋናፅፈት ቤት ህንፃ በስተ ቀኝ ባለው አስፓልት 20ሜትር ዝቅ እንዳሉ ሀበሻ ኮፊ የሚገኝበት ቀይ ሸክላ ህንፃ 2ተኛ ፎቅ ላይ ያገኙናል
#
# ክቡራን ደምበኞቻችን ገርጂ አልፎዝ ፕላዛ ላይ አራት ኪሎ ቅድስት ስላሴ ያሉት ሱቆቻችን ሲመጡ  አስተማማኝ ሰፊ ፓርኪንግ ያላቸው መሆናቸውን በታላቅ ደስታ እናበስራለን🙏🙏🙏
# [SINA KIDS/ሲና ኪድስⓇ] 2025-01-11 16:24:00+00:00: ክቡራን ደምበኞቻችን እሁድ ገርጂ የሚገኘው ሱቃችን ከጠዋት 4 ሰሀት ጀምሮ ክፍት መሆኑን ስንገልፅ በታላቅ አክብሮት ነው 🙏
# Fetching messages from channel: Shewa Brand
# [Shewa Brand] 2025-01-16 10:34:04+00:00: adidas CAMPUS
# Size 36#37#38#39
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-15 09:51:55+00:00: adidas CAMPUS
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-14 13:56:55+00:00: NIKE ZOOM 2024
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-13 11:03:41+00:00: NIKE VOMERO
# Size 40#41#42#43#44
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-11 08:09:00+00:00: SKECHERS GO RUN
# Size 36#37#38#39#40
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-09 10:31:45+00:00: Lv Trainer 54
# Size 40#41#42#43#44
# MADE IN ITALY
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-08 12:15:59+00:00: SKECHERS OUTDOOR
# Size 36#37#38#39
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-07 07:02:47+00:00: " ከዕለት ከሰዓት አስቀድሞ የነበረ ቀዳማዊ ሲሆን የአለም መድሀኒት እነሆ ዛሬ ተወለደ እንኳን ለጌታችን ለመድሃኒታችን ለእየሱስ ክርስቶስ የልደት በአል በሰላም በፍቅር አደረሳችሁ አደረሰን በአሉ የሰላም የፍቅር የመተሳሰብ እንዲሆንላችሁ ይመኛል shewa brand መልካም በአል
# [Shewa Brand] 2025-01-04 15:14:50+00:00: ALLSTAR CONVERSE lezear
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-04 06:46:32+00:00: NIKE HOT STEP air terra
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-03 15:54:30+00:00: LOWA GORIE-TEX
# Size 40#41#42#43
# MADE IN SOVAKIK
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-03 11:28:10+00:00: ALLSTAR Chuck Tayler OX
# Size 35--44
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-02 10:37:04+00:00: adidas X speedportal
# Size 39#40#41#42#43#44#45
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-02 10:36:53+00:00: adidas X speedportal
# Size 39#40#41#42#43#44#45
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-02 09:35:39+00:00: SKECHERS Arch fit comfort
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-01 14:59:44+00:00: NIKE ZOOM X
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-01 14:59:40+00:00: NIKE ZOOM X
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2025-01-01 09:44:19+00:00: NIKE LUNAR
# Size41#42#43#44#45
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2024-12-30 10:58:48+00:00: Nike zoom 2024
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0948595409 ይደውሉልን
# [Shewa Brand] 2024-12-27 15:57:03+00:00: አልቆ የነበረዉ ALLSTAR CONVERS X TODD በድጋሚ አስገብተናል
# Size 40#41#42#43
# MADE IN VIETNAM
# SHEWA BRAND
# አድራሻ ድሬዳዋ አሸዋ ሚና ህንፃ 1ኛ ፎቅ ላይ እንገኛለን
# የቴሌግራም ቻናላችንን ይቀላቀሉ
# 👇👇👇
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# https://t.me//shewabrand
# የቤት ቁጥር 109 እና 110
# 📩በ inbox  @shewat2 አዋሩን
#
# 📞 0987336458
# 📞0939395045 ይደውሉልን
# Fetching messages from channel: HellooMarket
# [HellooMarket] 2025-01-18 06:17:48+00:00: የወንዶች ባህላዊ አልባሳት!
# ለማዘዝ 8420 ላይ ይደውሉ አልያም የቴሌግራም ቦታችንን ይጠቀሙ
# https://t.me/helloo_market_bot?start=0924-10038
# Men's cultural well designed embroidered short sleeved shirt.
# Call 8420 or use our Telegram Bot on
# https://t.me/helloo_market_bot?start=0924-10038 #TraditionalFashion
# [HellooMarket] 2025-01-18 06:15:14+00:00: እንኳን ለከተራ እና ለጥምቀት በዓል በሰላም አደረሰዎ!
# ሃሎ ማርኬት!
# [HellooMarket] 2025-01-17 09:42:36+00:00: ለማዘዝ 8420 ይደውሉ: Call 8420 to order
# ● የሚያምሩ የሴቶች ባህላዊ አላባሽ በተለያየ ንድፍ ይዘዙ!
# 📌ለማዘዝ ከታች ያለውን ሊንክ ይጠቀሙ!
# https://t.me/helloo_market_bot?start=016110027
#  ●Order traditional beautiful women’s top with a different design!
# 📌to order use the link below!
# https://t.me/helloo_market_bot?start=016110027
# ● የሃሎማርኬት አቅራቢ ሆነው ይመዝገቡ! ያለማስያዣያ በተመቻቸሎት የብድር አገልግሎት ተጠቃሚ ይሁኑ!  #TraditionalFashion
# [HellooMarket] 2025-01-16 10:17:04+00:00: ጤናማ ለሰውነት ጠቃሚ ንጥረ—ነገሮችን ያካተተ በፈለጉት ሰዓት የሚያጣጥሙት ትሩ ላቭ ግራኖላ ባይትስ ለማዘዝ 8420 ይደውሉ ወይም https://t.me/helloo_market_bot?start=173910001 ይጠቀሙ!
# #Madeinethiopia #GroceryAndGourmet #Snacks #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-15 08:54:00+00:00: ምቹ የወንዶች ቁምጣ እና ቲሸርት ለማዘዝ 8420 ይደውሉ ወይም https://t.me/helloo_market_bot?start=004010057 ይጠቀሙ!
# ቀለም: ጥቁር እና ውሀ ሰማያዊ
# መጠን: XL
# #Madeinethiopia #MensFashion #MensCloth #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-13 10:07:23+00:00: በተዋበ ዲዛይን ለአያያዝ ምቹ ከቆዳ የተሰራ የሴቶች ቦርሳ ለማዘዝ 8420 ይደውሉ ወይም https://t.me/helloo_market_bot?start=011210001 ይጠቀሙ!
# #Madeinethiopia #WomensFashion  #BagsAndWallet #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-12 10:47:23+00:00: ዘናጭ ለሁለቱም ፃታ የሚለበስ ጆኬት በተለያዮ የቀለም እማራጯች ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=092410048 ይጠቀሙ!
# መጠን:M,L,XL
# ቀለም:ጥቁር በግራጫ እና ጥቁር በቀይ
# #Madeinethiopia #WomensCloth #MensCloth #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-11 13:12:51+00:00: ጂኤስቲ 100% ቫይታሚን ኢ የፀሐይን ጉዳት ለመከላከል እና የቆዳ መሸብሸብ፣ ጥቁር ነጠብጣቦች እና ብጉር ከገጽታ ለማሻሻል የሚረዳ የፊት ክሪም  ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=117110021
# #Madeinethiopia  #BeautyProducts  #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-10 10:01:18+00:00: ብዙ ተወዳጀነትን የተረፈ የቃልኪዳን ጉዞ ለሁሉም እድሜ የሚሆን የአማረኛ ስዕላዊ እና መሳጭ ታሪክ በቀለም እትመት ለማዘዝ 8420 ይደውሉ ወይም https://t.me/helloo_market_bot?start=121910003 ይጠቀሙ!
# #Madeinethiopia #Books #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-09 11:45:49+00:00: ዘናጭ ዘመናዊ  ከሁሉም አለባበስ ጋር የሚስማማ የወንዳች ቲሸርት ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=176110001 ይጠቀሙ!
# #Madeinethiopia #MensFashion  #MensCloth #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-08 07:24:24+00:00: የሴቶች ውብ እና ባማረ ዲዛይን የተሰሩ ኮቶችን በተለያየ የቀለም አማራጭ ለማዘዝ 8420 ይደውሉ ወይም https://t.me/helloo_market_bot?start=102242 ይጠቀሙ!
# መጠን: Free Size
# #Madeinethiopia #WomensFashion  #WomensCloth #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-07 05:01:34+00:00: እንኳን ለኢየሱስ ክርስቶስ ልደት በዓለ በሰላም አደረሳችሁ!
# #Madeinethiopia  #Ethiopian #Marketplace #BuyEthiopia
#
# ሃሎ ማርኬት
# [HellooMarket] 2025-01-05 13:51:23+00:00: መልካም ገና!!
# የሴቶች ዘመናዊ እና ምቹ ቀሚስ ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=092410043 ይጠቀሙ!
# #Madeinethiopia #WomensCloth #WomensFashion #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-04 22:19:35+00:00: የልጆች ወብ ባማረ ዲዛይን የተሰራ ቀሚስ ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=176010001 ይጠቀሙ!
# መጠን: S: L እና M
# #Madeinethiopia #Kids #KidsFashion #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-03 11:40:04+00:00: በተለያየ የቀለም አማራጭ ተጨማሪ ውበት ከሚሰጥ ከለስላሳ ጨርቅ የተሰራ ዘናጭ ታይት ከነአላባሹ  ለማዘዝ 0974312223 ይደውሉ ወይም http://t.me/helloo_market_bot?start=035210016 ይጠቀሙ!
# #Madeinethiopia #WomensFashion  #WomensCloth #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-03 08:55:53+00:00: ለቤቶ አልያም ለቤሮዎ ቱሊፕ የወሃ ማጣሪያ ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=174410001 ይጠቀሙ!
# መጠን:16 ሊትር
# #Madeinethiopia #HomeAppliances #KitchenAppliance #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-02 09:57:07+00:00: ከፈለጉት የአለባበስ ዘይቤጋር የሚሄድ ባህላዊ ልብስ ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=092410038 ይጠቀሙ!
# #Madeinethiopia #MensCloth #TraditionalFashion #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2025-01-01 07:11:15+00:00: እንዲህ ድምቅ ባለ ባህላዊ የሴቶች አላባሽ  ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=102533 ይጠቀሙ!
# #Madeinethiopia #WomensFashion #WomensCloth #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2024-12-30 07:59:54+00:00: በተለያየ የቀለም አማራጭ ተጨማሪ ውበት ከሚሰጥ ከለስላሳ እና ምቹ ጨርቅ የተሰራ ዘናጭ ታይት ለማዘዝ 0974312223 ይደውሉ ወይም http://t.me/helloo_market_bot?start=174810008 ይጠቀሙ!
# #Madeinethiopia #WomensFashion  #WomensCloth #Ethiopian #Marketplace #BuyEthiopia
# [HellooMarket] 2024-12-28 16:45:08+00:00: አስደናቄ አትዮጵያዊ ምስልሎች ያላቸው የአረቄ መለኪያ ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=160010001 ይጠቀሙ!
# #Madeinethiopia #HomeDecor  #Ethiopian #Marketplace #BuyEthiopia
# Fetching messages from channel: ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER
# [ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER] 2025-01-17 12:26:50+00:00: **ቴሌግራም****🫐**** **t.me/modernshoppingcenter**
#      "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን"
#
# ****🔤****🔤****🔤****🔤****🔤****🔤****🔤****
#           ****🔤****🔤****🔤****🔤****🔤****🔤****
#                      ****🔤****🔤****🔤****🔤****🔤****🔤**
#
# 🔤 **የፍራፍሬ መጭመቂያ
# ****🔤**** ብርቱካን ፤ ሎሚ ፤ አፕል የመሳሰሉትን በቀላሉ የሚጨምቅ
# ****🔤**** 700ml የመያዝ አቅም ያለው
# ****🔤**** የራሱ ማውረጃ ያለው
# ****🌹**** ሞተሩ ጠንካራ የሆነ
# ****🔤**** ለማፅዳት ቀላል
# ****🔤**** ለአጠቃቀም ምቹ
#
#                   በ****📥****
#             ****💵****2800****💵****
#
# ****☃️**** የቲክ ቶክ ፔጃችንን ለማግኘት ሊንኩን ይጫኑ ****⬇️****
# ****http://tiktok.com/@modernshoppingcenter1****
#
# ****📞**** ****0924743736****
# ****📞**** ****0974978584****
#
# በስራችን ላይ ቅሬታ ካለዎት ብቻ በዚህ ስልክ ደዉለዉ ያሳዉቁን። ****🔽****
#                       ****📞****  **0961373839**
#
# ****✈️**** የመረጡትን እቃ ለማዘዝ ከታች ባለዉ የቴሌግራም አድራሻ ይላኩልን
#
# ****💬**** **t.me/modernshopping1**
# ****💬**** **t.me/modernshopping2**
#
# **🏍🏍**አዲስ አበባ ዉስጥ ከ150ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# ****⚡️****⚡️**** ለክፍለ ሀገር ደንበኞቻችን በመነሐሪያ በኩል አድርገን በሹፌር እንልካለን።
#
# ****❓**** አድራሻ
#
#       ቁጥር ****1️⃣**** = ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ( ሆሊ ሲቲ ሴንተር ሞል ) ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል  ሚዛን ላይ M06
#        ቁጥር ****2️⃣**** = ጀሞ መስታወት ፋብሪካ ጭስ መዉጫዉ ፊት ለፊት ( ራሐ ሞል ) ግራዉንድ ፍሎር ከደረጃዉ ጎን RM G-06 (ትልቁ ሚና ፈርኒቸር ያለበት ህንፃ)
#
#          ****⭐️**** "በሞደርን እቃወዏች ሂወትዎን
#                    ሞደርናይዝ ያድርጉ "****⭐️**
# [ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER] 2025-01-17 07:49:42+00:00: **ቴሌግራም👉t.me/modernshoppingcenter****
#      "በአዲስ ነገር ሁሌም ቀዳሚዏች ነን"
#
# ****🔠****🔠****🔠****🔠****🔠****🔠****🔠****
#
#             ****🔠****🔠****🔠****🔠****🔠****🔠****🔠****
#
# ****🔤**** አዲስ የጤና መጠበቂያ ማሽን
# ****🔤**** በዚህ ማሽን ለ 15 ደቂቃ መጠቀም 5ኪሎሜትር ሩጫ ከመሮጥ ፣2 ሰአት የሰውነት እንቅስቃሴ ከመስራት የበለጠ ጥቅም ይሰጣል
# ****🔤**** የደም ዝዉዉርን ያስተካክላል
# ****🔤**** የስኳርናየኮሊስትሮል መጠንን ያስተካክላል
# ****🔤**** አጠቃላይ የሰውነት ነርቮችን ስራቸዉን በትክክል እንዲያከናዉኑ ይረዳል
# ****🔤**** አላስፈላጊ የስብ ክምችትን ከሰዉነታችን እንዲወገዱ ያደርጋል
# ****🔤**** የደም ግፊት የሚያመጣዉን የታይሮይድ እጢን ስራ ያስተካክላል
# ****🔤**** የደም መፍሰስን ያስወግዳል
# የተለያዩ ህመሞችን ለማስወገድ ይረዳል
# ****🔤**** ለቁመት እድገት ይረዳል
# ****🔤**** በአጠቃላይ በሴሉላር ደረጃ በሚገኙ የሰዉነትችን ክፍሎች ለይ ስራዉን ይሰራል።
# ****🔤**** እንደነ አሊባባ ያሉ አለም አቀፍ ድርጅቶች በፊት ገፃቸው ላይ የለጠፉት አስተማማኝ እቃ
#
#               በ****📥****
#         ****💵**7**000****💵****
#
# ****☃️**** የቲክ ቶክ ፔጃችንን ለማግኘት ሊንኩን ይጫኑ ****⬇️**
# http://tiktok.com/@modernshoppingcenter1**
#
# ****📞**** **0924743736**
# ****📞**** **0974978584**
#
# በስራችን ላይ ቅሬታ ካለዎት ብቻ በዚህ ስልክ ደዉለዉ ያሳዉቁን። ****🔽****
#                       ****📞****  **0961373839**
#
# ****✈️**** የመረጡትን እቃ ለማዘዝ ከታች ባለዉ የቴሌግራም አድራሻ ይላኩልን
#
# ****💬**** **t.me/modernshopping1**
# ****💬**** **t.me/modernshopping2**
#
# **🏍🏍**አዲስ አበባ ዉስጥ ከ150ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# ****⚡️****⚡️**** ለክፍለ ሀገር ደንበኞቻችን በመነሐሪያ በኩል አድርገን በሹፌር እንልካለን።
#
# ****❓**** አድራሻ
#
#       ቁጥር ****1️⃣**** = ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ( ሆሊ ሲቲ ሴንተር ሞል ) ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል  ሚዛን ላይ M06
#        ቁጥር ****2️⃣**** = ጀሞ መስታወት ፋብሪካ ጭስ መዉጫዉ ፊት ለፊት ( ራሐ ሞል ) ግራዉንድ ፍሎር ከደረጃዉ ጎን RM G-06 (ትልቁ ሚና ፈርኒቸር ያለበት ህንፃ)
#
#          ****⭐️**** "በሞደርን እቃወዏች ሂወትዎን
#                    ሞደርናይዝ ያድርጉ "****⭐️**
# [ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER] 2025-01-16 15:18:29+00:00: **ቴሌግራም****🫐**** **t.me/modernshoppingcenter**
#      "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን"
#
#     ****🔠****🔠****🔠****🔠****  ****🔠****🔠****🔠****🔠****
#
#   ****🔠****🔠****🔠****🔠****🔠****🔠****🔠****🔠****🔠****
#
# ****🔤**** የልጆች ምግብ መስሪያ
# ****🔤**** በከፍተኛ ሙቀት ምግብን እስቲም የሚያደርግ
# ****🔤**** እስቲም ያደረገውን የሚደባልቅ ወይም የሚፈጭ
# ****🔤**** ምላጩ እስቴለስ እስቲል የሆነ
# ****🔤**** ጆጉ 500ml የመያዝ አቅም ያለው
# ****🔤**** mixing power 110W
# ****🔤**** Heating power 300W
# ****🔤**** ለማፅዳት ቀላል
# ****🔤**** ለአጠቃቀም ምቹ**
# **
#                   በ****📥****
#                 ****💵****💵****
#
# ****☃️**** የቲክ ቶክ ፔጃችንን ለማግኘት ሊንኩን ይጫኑ ****⬇️**
# http://tiktok.com/@modernshoppingcenter1**
#
# ****📞**** **0924743736**
# ****📞**** **0974978584**
#
# በስራችን ላይ ቅሬታ ካለዎት ብቻ በዚህ ስልክ ደዉለዉ ያሳዉቁን። ****🔽****
#                       ****📞****  **0961373839**
#
# ****✈️**** የመረጡትን እቃ ለማዘዝ ከታች ባለዉ የቴሌግራም አድራሻ ይላኩልን
#
# ****💬**** **t.me/modernshopping1**
# ****💬**** **t.me/modernshopping2**
#
# **🏍🏍**አዲስ አበባ ዉስጥ ከ150ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# ****⚡️****⚡️**** ለክፍለ ሀገር ደንበኞቻችን በመነሐሪያ በኩል አድርገን በሹፌር እንልካለን።
#
# ****❓**** አድራሻ
#
#       ቁጥር ****1️⃣**** = ጉርድሾላ ከሴንቸሪ ሞል ትንሽ ዝቅ እንዳሉ ( ሆሊ ሲቲ ሴንተር ሞል ) ላይ እንደገቡ ፊትለፊት ከሊፍቱ በግራ በኩል  ሚዛን ላይ M06
#        ቁጥር ****2️⃣**** = ጀሞ መስታወት ፋብሪካ ጭስ መዉጫዉ ፊት ለፊት ( ራሐ ሞል ) ግራዉንድ ፍሎር ከደረጃዉ ጎን RM G-06 (ትልቁ ሚና ፈርኒቸር ያለበት ህንፃ)
#
#          ****⭐️**** "በሞደርን እቃወዏች ሂወትዎን
#                    ሞደርናይዝ ያድርጉ "****⭐️**
# [ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER] 2025-01-16 07:38:01+00:00: **ቴሌግራም****🫐**** **t.me/modernshoppingcenter**
#      "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን"
# **
# ✔️ **የፍራፍሬ አና የፓስታ ማጥለያ
# ****✔️**** እስቴለስ እስቲል ስለሆነ የማይዝግ እና ረዘም ላለ ጊዜ የሚያገለግል
# ****✔️**** ለአጠቃቀም ቀላል
#
#      3ቱን      በ****📥****
#             ****💵****1500****💵****
#
# ****☃️**** የቲክ ቶክ ፔጃችንን ለማግኘት ሊንኩን ይጫኑ ****⬇️**
# ...
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 4900
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# [BELLA CLASSIC®] 2025-01-14 21:13:01+00:00: 👟 brand :- OXFORD CASUAL LAZY
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 4900
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# [BELLA CLASSIC®] 2025-01-14 21:04:11+00:00: 👟 brand :- OXFORD CASUAL LAZY
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 4900
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# [BELLA CLASSIC®] 2025-01-14 20:58:01+00:00: 👟 brand :- OXFORD CASUAL TIE
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 4900
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# [BELLA CLASSIC®] 2025-01-14 15:59:00+00:00: 👟 brand :- OXFORD CASUAL TIE
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 4900
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# [BELLA CLASSIC®] 2025-01-14 14:09:55+00:00: 👟 brand :- OXFORD CASUAL TIE
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 4900
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# [BELLA CLASSIC®] 2025-01-14 13:34:55+00:00: 👟 brand :- OXFORD CASUAL TIE
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 4900
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# [BELLA CLASSIC®] 2025-01-14 11:31:59+00:00: 👟 brand :- LUKAI MC
# 📐 size  :-  39,40,41,42,43,44
#
# 💰 ዋጋ :- 3600
# ☎️ ስልክ :- 0944222069
# 📥 በውስጥ ለማናገር :- @Bellaclassics
#
# 🏘 አድራሻ :- ሜክሲኮ ኬኬር ህንፃ 2ኛ ፎቅ በመጀመሪያው በስተቀኝ እጥፍ ሲሉ ሱቅ.ቁ213
# Fetching messages from channel: AwasMart-አዋስማርት🎁
# [AwasMart-አዋስማርት🎁] 2025-01-18 05:33:44+00:00: 👼Baby care kit👼
# [AwasMart-አዋስማርት🎁] 2025-01-18 05:33:44+00:00: 🤱Portable Health Care Kit🐥
#     🔐Designed For Newborn Babies
#
# 👉 13 pieces of baby care set, stored in a carton for easy storage & organizing
#
# ✔️ Simple, convenient and easy to use.
# ✔️Made of green materials to care for the baby’s growth
# ✔️ effectively protect baby’s health
# ✔️100% new and high quality
#
# #Package_Included:
# 1× Hair care brush
# 1× Digital thermometer
# 1× Nail clipper
# 1× Tweezers
# 1× Round head scissor
# 1× Comb
# 1× Measurement straw
# 1× Nail file
#
# 📌 Color: #Blue & #Pink
#
#        ዋጋ💵፦  💰1,000 ብር
#
# 💬በቴሌግራም ለማዘዝ @awasadmin1
#                                         @awasadmin2
#
# 📍አድራሻችን:-
# 1️⃣.📌መገናኛ ኪኔሬት ሕንፃ 1ኛ ፎቅ ቁ. 101 (ዋአች ሕንፃ ፊትለፊት ንግድ ባንክ እና ጎህ ቤቶች ባንክ ያሉበት)
#
# 2️⃣.📌 ሜክሲኮ አልሳም አፓርታማ ግራውንድ ቁ. 29
#
# 3️⃣.📌 ቦሌ መድሐኔዓለም ቦሌ መሰናዶ ት/ቤት ፊትለፊት አለምነሽ ፕላዛ ግራውንድ ሱቅ ቁጥር 05
#
# 📻(+251941661030 / +251943190237)
#
# 👍ለወዳጅዎ ስላጋሩ እናመሠግናለን ☺️
#
# 🔔 ቴሌግራም ቻናል t.me/AwasMart
# [AwasMart-አዋስማርት🎁] 2025-01-17 17:45:25+00:00: ❇️ **__Rechargeable Vintage Lamp Humidifier__**
# [AwasMart-አዋስማርት🎁] 2025-01-17 17:44:05+00:00: ❇️ **__Rechargeable Vintage Lamp Humidifier__**
#          `💯High-quality `
#
#
# **☛በኤሌክትሪክ የሚሰራ
# ☛ለቤት መልካም መዓዛን የሚሰጥ**
#
# __👉Continuously spray for 6 hours & automatically power off
# ✓Capacity: 280ml
# ✓Spray Amount: 25 -40ml/H
# ✓Battery Capacity: 1,200mAh
# ✓Power: 1.5W
# ✓Brightness level: 1%-100%
# ✓Purify the air & Beautify the Environment
#
# **☛**__#Vintage_Lamp_Humidifier__
# ✓Compact and portable
# ✓Healthy mist
# ✓Gentle warm light
# ✓Colorful Atmosphere Light
# ✓Second-speed Spray
# ✓Wireless Humidification
#
# 👉Suitable for home, office, bedroom, living room, bathroom, car, etc.
#
# __☛#Package_Included__**:**
# 1 x Humidifier
# 1 x USB Cable__
#
#     ዋጋ🫰፦  💰1,800 ብር
#
# 👉💬በቴሌግራም ለማዘዝ @awasadmin1
#                                         @awasadmin2
#
# 📍አድራሻችን:-
# 1️⃣.📌መገናኛ ኪኔሬት ሕንፃ 1ኛ ፎቅ ቁ. 101 (ዋአች ሕንፃ ፊትለፊት ንግድ ባንክ እና ጎህ ቤቶች ባንክ ያሉበት)
#
# 2️⃣.📌 ሜክሲኮ አልሳም አፓርታማ ግራውንድ ቁ. 29
#
# 3️⃣.📌 ቦሌ መድሐኔዓለም ቦሌ መሰናዶ ት/ቤት ፊትለፊት አለምነሽ ፕላዛ ግራውንድ ሱቅ ቁጥር 05
#
# 📻(+251941661030 / +251943190237)
#
# 👍ለወዳጅዎ ስላጋሩ እናመሠግናለን ☺️
#
# 🔔 ቴሌግራም ቻናል t.me/AwasMart
# Fetching messages from channel: qnash.com - ቅናሽ ®️
# 2025-01-18 10:15:51,240 - INFO - Disconnecting from 149.154.167.91:443/TcpFull...
# 2025-01-18 10:15:51,241 - INFO - Disconnection from 149.154.167.91:443/TcpFull complete!
# [qnash.com - ቅናሽ ®️] 2025-01-17 16:41:32+00:00: 📣 Hair Steamer Cap
# 🔼 High Quality
#
# ➡️የፀጉር እስቲመር ትሪትመንት ወይም ቅቤ ተቀብተው በቤቶ ሆነው የሚጠቀሙበት
#
#           💵ዋጋ፦ **1000ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
# < Limited Stock ❌
#
# Telegram - t.me/qnashcom
# ✅ ጥራት ✅ ዋስትና ✅ ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-17 11:35:59+00:00: 📣 Hair Steamer Cap
# 🔼 High Quality
#
# ➡️የፀጉር እስቲመር ትሪትመንት ወይም ቅቤ ተቀብተው በቤቶ ሆነው የሚጠቀሙበት
#
#           💵ዋጋ፦ **1000ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
# < Limited Stock ❌
#
# Telegram - t.me/qnashcom
# ✅ ጥራት ✅ ዋስትና ✅ ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-17 09:01:41+00:00: 🟰🔡🔣🟰ለደረቅ ነገሮች መፍጫ የቀረበ
# ➡️GRINDER Machine
# ➡️የቡና እና የቅመማ ቅመም መፍጫ
# ማንኛዉንም ደረቅ ነገር በሰከንዶች የሚፈጭ
# 1ኛ ደረጃ ኦሪጅናል ዕቃ NEW imported
#
# 🔥እጅግ በጣም ጠንካራ
# 🔥ለደረቅ ቅመማ ቅመሞች የሚሆን
# 🔥ሙሉ ለሙሉ ብረት (Stainless steel)
# 🔥የራሱ መለዋወጫ ጥርስ ያለው
#
# በ 100 ግ  ✔️ **3700 ብር**
# በ 200 ግ  ✔️ **4800 ብር**
#
# 📣 ለማዘዝ = @Orderqnashplus
#
# ❌ ዲሊቨሪ ብቻ
# 📌 Delivery Only
#
#
# Telegram - t.me/qnashplus 👉
#
# ☄️ጥራት+ ✔️ ዋስትና+ 🛍 ቅናሽ+
#
# ስልክ:
# 📱0916767778
# 📱0916767778
# [qnash.com - ቅናሽ ®️] 2025-01-17 09:01:41+00:00: 🟰🔡🔣🟰ለደረቅ ነገሮች መፍጫ የቀረበ
# ➡️GRINDER Machine
# ➡️የቡና እና የቅመማ ቅመም መፍጫ
# ማንኛዉንም ደረቅ ነገር በሰከንዶች የሚፈጭ
# 1ኛ ደረጃ ኦሪጅናል ዕቃ NEW imported
#
# 🔥እጅግ በጣም ጠንካራ
# 🔥ለደረቅ ቅመማ ቅመሞች የሚሆን
# 🔥ሙሉ ለሙሉ ብረት (Stainless steel)
# 🔥የራሱ መለዋወጫ ጥርስ ያለው
#
# በ 100 ግ  ✔️ **3700 ብር**
# በ 200 ግ  ✔️ **4800 ብር**
#
# 📣 ለማዘዝ = @Orderqnashplus
#
# ❌ ዲሊቨሪ ብቻ
# 📌 Delivery Only
#
#
# Telegram - t.me/qnashplus 👉
#
# ☄️ጥራት+ ✔️ ዋስትና+ 🛍 ቅናሽ+
#
# ስልክ:
# 📱0916767778
# 📱0916767778
# [qnash.com - ቅናሽ ®️] 2025-01-17 05:14:52+00:00: 🔥🔥 **Saachi Touch Stove Ceramic Cooker**
#
# 📣 ባለ አንድ
# 📣 A Grade Black Crystal Palte
# 📣 High Efficient Heating
# 📣 6 Cooking Function
# 📣 Lock Function
# 📣 1750 W
#
# 📌 ፍሳሽ የማያስገባ
# 💯የፈለጉትን ድስት የሚጥዱበት
# 🟢ቴርሞስታት የተገጠመለት
#
# 💵**3800 ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
#
# Telegram - t.me/qnashcom
# ⚡️ጥራት 🔼 ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# 🗺ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# 🗺ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱 0946966440
# 📱 0992606060
# 📱 0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-16 16:28:49+00:00: ⚡️➡️**KEMEI PROFESSIONAL HAIR CLIPPER**
#
# ⚡️🔼Kemei የፀጉር ማስተካከያ
#
# 💯 ከፍተኛ ጥራት
#
# ✂️የራስ ፀጉር እና ፂምን በስርአት እና በጥራት ለማስተካከል አስተማማኝ ማሽን
# ✂️በሚፈልጉት መጠን ለመቁረጥ መቀያየሪ ቁጥሮች ያሉት
# ✂️በቻርጅ የሚሰራ አስተማምኝ ባትሪ
#
# ✂️High quality material
# ✂️Professional Hair Clippers
# ✂️Adjustable Taper Lever
# ✂️chargeable and strong battery
#
# 📣 **ለማዘዝ = **@Orderqnash
#
# 💵 **2600** ብር ብቻ
#
# ✔️ ስለ ዕቃወቹ መረጃ እና ቪዲዮዎች ለማየት ቴሌግራማንን ይቀላቀሉ
# Telegram - t.me/qnashcom
#
# ውስን ፍሬ ነው የቀረው ❌
# Limited Stock ‼️
#         📌  ይፍጠኑ
#
# Telegram - t.me/qnashcom
# 🔼ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# **ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329**
#
# **ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-16 12:07:30+00:00: ⚡️➡️**KEMEI PROFESSIONAL HAIR CLIPPER**
#
# ⚡️🔼Kemei የፀጉር ማስተካከያ
#
# 💯 ከፍተኛ ጥራት
#
# ✂️የራስ ፀጉር እና ፂምን በስርአት እና በጥራት ለማስተካከል አስተማማኝ ማሽን
# ✂️በሚፈልጉት መጠን ለመቁረጥ መቀያየሪ ቁጥሮች ያሉት
# ✂️በቻርጅ የሚሰራ አስተማምኝ ባትሪ
#
# ✂️High quality material
# ✂️Professional Hair Clippers
# ✂️Adjustable Taper Lever
# ✂️chargeable and strong battery
#
# 📣 **ለማዘዝ = **@Orderqnash
#
# 💵 **2600** ብር ብቻ
#
# ✔️ ስለ ዕቃወቹ መረጃ እና ቪዲዮዎች ለማየት ቴሌግራማንን ይቀላቀሉ
# Telegram - t.me/qnashcom
#
# ውስን ፍሬ ነው የቀረው ❌
# Limited Stock ‼️
#         📌  ይፍጠኑ
#
# Telegram - t.me/qnashcom
# 🔼ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# **ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329**
#
# **ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-16 07:09:50+00:00: ➡️🟢**Manual Vegetable Cutter** Slicer Kitchen Roller Gadgets Tool Vegetable Chopper Round Slicer Graters Potato Carrot Cheese Shredder
#
#    💵**1250 ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
#
# Telegram - t.me/qnashcom
# ⚡️ጥራት 🔼 ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# 🗺ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# 🗺ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱 0946966440
# 📱 0992606060
# 📱 0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-15 16:17:40+00:00: 📣🔼 Foldable Height Adjustable Metal Frame Laptop Stand
# Help your sitting posture
# ☄️ High  Quality ( የብረቱ )
#
# ➡️ ላፕቶፕ ጭን ላይ አስቀምጠው መጠቀም ለከፋ ጉዳት እንደሚያጋልጥ የጤና ባለሙያዎች ይናገራሉ ፤ እንዲሁም ቴብል ላይ አድርገዉ ሲጠቀሙ ፋኑ ስለሚደፈን  ከፍተኛ ሙቀት በመጠር ድምፅ ያሰማል።
# ለዚህ ሁሉ መፍትሄ ተጣጣፊ የላፕቶፕ ፣ ታብሌት Holder በተመጣጣኝ ዋጋ ገዝተዉ የእርስዎንና የላፕቶፕዎን ጤንነት ይጠብቁ።
#
#                  💵** ****✔️****1100 ብር**
#
# 📌**Black color available**
#
# 📣 ለማዘዝ = @Orderqnash
#
# Telegram - t.me/qnashcom 👉
#
# ☄️ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329
#
# ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-15 16:12:31+00:00: 📣🔼 Foldable Height Adjustable Metal Frame Laptop Stand
# Help your sitting posture
# ☄️ High  Quality ( የብረቱ )
#
# ➡️ ላፕቶፕ ጭን ላይ አስቀምጠው መጠቀም ለከፋ ጉዳት እንደሚያጋልጥ የጤና ባለሙያዎች ይናገራሉ ፤ እንዲሁም ቴብል ላይ አድርገዉ ሲጠቀሙ ፋኑ ስለሚደፈን  ከፍተኛ ሙቀት በመጠር ድምፅ ያሰማል።
# ለዚህ ሁሉ መፍትሄ ተጣጣፊ የላፕቶፕ ፣ ታብሌት Holder በተመጣጣኝ ዋጋ ገዝተዉ የእርስዎንና የላፕቶፕዎን ጤንነት ይጠብቁ።
#
#                  💵** ****✔️****1100 ብር**
#
# 📌**Black color available**
#
# 📣 ለማዘዝ = @Orderqnash
#
# Telegram - t.me/qnashcom 👉
#
# ☄️ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329
#
# ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-15 10:11:20+00:00: 📣🔼 Foldable Height Adjustable Metal Frame Laptop Stand
# Help your sitting posture
# ☄️ High  Quality ( የብረቱ )
#
# ➡️ ላፕቶፕ ጭን ላይ አስቀምጠው መጠቀም ለከፋ ጉዳት እንደሚያጋልጥ የጤና ባለሙያዎች ይናገራሉ ፤ እንዲሁም ቴብል ላይ አድርገዉ ሲጠቀሙ ፋኑ ስለሚደፈን  ከፍተኛ ሙቀት በመጠር ድምፅ ያሰማል።
# ለዚህ ሁሉ መፍትሄ ተጣጣፊ የላፕቶፕ ፣ ታብሌት Holder በተመጣጣኝ ዋጋ ገዝተዉ የእርስዎንና የላፕቶፕዎን ጤንነት ይጠብቁ።
#
#                  💵** ****✔️****1100 ብር**
#
# 📌**Black color available**
#
# 📣 ለማዘዝ = @Orderqnash
#
# Telegram - t.me/qnashcom 👉
#
# ☄️ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329
#
# ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-15 05:17:23+00:00: **♨️♨️****🔥**** Boma Electric Kettle 6 ሊትር**
#
# **✈️**** ከፍተኛ ጥራት **
#
# 🔥Quality In Germany Price In China
# 🔥6 ሊትር
# 🔥1800 ዋት
# 🔥Automatic Shutdown
# 🔥 Removable and Washable Filter
# 🔥 360° Cordless Power Socket
# 🔥Water Level indicator
#
#        💵**4500 ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
#
# Telegram - t.me/qnashcom
# ⚡️ጥራት 🔼 ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# 🗺ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# 🗺ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱 0946966440
# 📱 0992606060
# 📱 0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-14 16:15:12+00:00: 📣🔥 Saachi Hot plate
# ሳቺ ባለሁለት ምድጃ ስቶቭ
#
# 🔥 2000 ዋት
# 🔥 ፊውዝ የተገጠመለት
# 🔥 ትልቅ ድስት መሸከም የሚችል
# 🔥 አስተማማኝ ቴርሞስታት
#
#     💲ዋጋ፦ ትልቁ = **3500 ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
# < Limited Stock ❌
#
# Telegram - t.me/qnashcom
# Website - www.qnash.com
# 🔼 ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 📍 አድራሻ ፦
# 🗺ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3ተኛ ፎቅ ቁጥር 329**
#
# 🗺ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-14 11:40:58+00:00: 🔣**Table Place Mats**🔡
#
# ❤️ ከፍተኛ ጥራት
# ✈️ waterproof
# ⚡ Oilproof
# 🟰 Non Slip
# 6️⃣ 6 Pcs
#
# ዋጋ💵፦ ። **6 ፍሬ 1500 ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
#
# Telegram - t.me/qnashcom
# ⚡️ጥራት 🔼 ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# 🗺ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# 🗺ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱 0946966440
# 📱 0992606060
# 📱 0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-14 11:28:19+00:00: 🔠🔠🔠🔠🔠🔠 🔠🔠🔠🔠
# **ቡና ማፍያ ማሽን**
# ✔️SKOEDI Single Cup Coffee Maker
# SKOEDI⬇️ Single Cup Coffee Maker With removal filter basket
# Reusable mesh filter Power button with indicator light
#
# ዋጋ💵፦ **3400 ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
#
# Telegram - t.me/qnashcom
# ⚡️ጥራት 🔼 ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# 🗺ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# 🗺ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱 0946966440
# 📱 0992606060
# 📱 0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-14 06:59:15+00:00: 🔠🔠🔠🔠🔠🔠 🔠🔠🔠🔠
# **ቡና ማፍያ ማሽን**
# ✔️SKOEDI Single Cup Coffee Maker
# SKOEDI⬇️ Single Cup Coffee Maker With removal filter basket
# Reusable mesh filter Power button with indicator light
#
# ዋጋ💵፦ **3400 ብር**
#
# ውስን ፍሬ ነው የቀረው ❌❌
#
# Telegram - t.me/qnashcom
# ⚡️ጥራት 🔼 ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# 🗺ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 **
#
# 🗺ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07 **
#
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱 0946966440
# 📱 0992606060
# 📱 0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-13 17:22:00+00:00: ⚡️ Foldable Electric Kettle – 600ml
# ✔️ተጣጣፊ የኤሌክትሪክ ሶኬት የሚሰራ ቦይለር
#
# 💯🔵 ለቢሮ, ለካንፓስ በጣም ተስማሚ
#
# 👉Foldable Electric Kettle with its new design completely collapsible for easy storage and travel.
#
# ☄️Foldable and Portable
# ☄️Easy to store
# ☄️Fast Boiling
# ☄️Capacity: 600ml
# ☄️Power: 600W
# ☄️Dry Protection
# ☄️No/off Switch Off
# ☄️Voltage: 220V
# ☄️Material: Silicone + Plastic
# ☄️304 Stainless Steel Heating Plate
#
# 💵 **1300** **ብር**
#
# 📣 **ለማዘዝ = **@Orderqnash
#
# **ውስን ፍሬ ነው የቀረው** ❌❌❌
#
# Telegram - t.me/qnashcom
# 🔼 ጥራት ✔️ዋስትና 🛍ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329**
#
# ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
# **
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-13 12:26:18+00:00: ⚡️ Foldable Electric Kettle – 600ml
# ✔️ተጣጣፊ የኤሌክትሪክ ሶኬት የሚሰራ ቦይለር
#
# 💯🔵 ለቢሮ, ለካንፓስ በጣም ተስማሚ
#
# 👉Foldable Electric Kettle with its new design completely collapsible for easy storage and travel.
#
# ☄️Foldable and Portable
# ☄️Easy to store
# ☄️Fast Boiling
# ☄️Capacity: 600ml
# ☄️Power: 600W
# ☄️Dry Protection
# ☄️No/off Switch Off
# ☄️Voltage: 220V
# ☄️Material: Silicone + Plastic
# ☄️304 Stainless Steel Heating Plate
#
# 💵 **1300** **ብር**
#
# 📣 **ለማዘዝ = **@Orderqnash
#
# **ውስን ፍሬ ነው የቀረው** ❌❌❌
#
# Telegram - t.me/qnashcom
# 🔼 ጥራት ✔️ዋስትና 🛍ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- **መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329**
#
# ቁጥር 2 :- **ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
# **
# ❌❌ **ማሳሰብያ**: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-13 12:23:13+00:00: 🔥📣 IINIMA® Coffee Grinder
#
# 📌Stainless Steel Bowl to mill
#         ⚡️coffee
#         ⚡️cardamom
#         ⚡️nut
#         ⚡️Spices
# ☄️150W
#
#                  💲1500 ብር
#
# Telegram - t.me/qnashcom 👉
#
# ☄️ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 📍አድራሻ ፦
# 🗺ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329
#
# 🗺ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# [qnash.com - ቅናሽ ®️] 2025-01-13 06:58:03+00:00: 🔥📣 IINIMA® Coffee Grinder
#
# 📌Stainless Steel Bowl to mill
#         ⚡️coffee
#         ⚡️cardamom
#         ⚡️nut
#         ⚡️Spices
# ☄️150W
#
#                  💲1500 ብር
#
# Telegram - t.me/qnashcom 👉
#
# ☄️ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 📍አድራሻ ፦
# 🗺ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329
#
# 🗺ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# 📱0905464599
# Disconnecting Telegram client...
# Client disconnected.

# %%
import csv
import re

# Function to read the "Message" column from the CSV file
def read_messages_from_csv(csv_file="result.csv"):
    messages = []
    with open(csv_file, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            message = row.get("Message Content", "").strip()  # Get the message from the "Message" column
            if message:  # Avoid empty messages
                messages.append(message)
    return messages

# Regular expression to detect Amharic characters (Unicode range for Amharic)
amharic_regex = re.compile('[\u1200-\u137F]+')

# Function to extract only Amharic text from the message
def extract_amharic_text(message):
    """
    This function extracts only the Amharic text from a given message.
    It returns the Amharic part of the message, or None if no Amharic text is found.
    """
    amharic_text = " ".join(re.findall(amharic_regex, message))
    return amharic_text if amharic_text else None

# Regular expressions for detecting different entities
product_keywords = ['ልብስ', 'ምንጣፍ', 'እንጀራ', 'ተለዋዋጭ', 'እቃ']
location_keywords = ['አበባ', 'ቦሌ', 'አዲስ', 'ተማ', 'እስትንፋስ', 'አዳም']
price_keywords = ['ዋጋ', 'ብር', 'ሴራ', 'በ']

# Function to label entities dynamically based on the message content
def dynamic_label_message(message):
    tokens = message.split()  # Simple whitespace-based tokenization
    labeled_tokens = []
    
    for token in tokens:
        label = "O"  # Default label (outside any entity)
        
        # Check if the token matches a known product keyword
        if any(keyword in token for keyword in product_keywords):
            label = "B-Product"  # Label as product (can extend to I-Product if needed)
        
        # Check if the token matches a known location keyword
        elif any(keyword in token for keyword in location_keywords):
            label = "B-LOC"  # Label as location (can extend to I-LOC if needed)
        
        # Check if the token matches a known price keyword
        elif any(keyword in token for keyword in price_keywords):
            label = "B-PRICE"  # Label as price (can extend to I-PRICE if needed)
        
        labeled_tokens.append((token, label))
    return labeled_tokens

# Save the labeled data in CoNLL format
def save_to_conll(messages, output_file="labeled_dataset.conll"):
    """
    Saves labeled data in CoNLL format.
    """
    with open(output_file, "w", encoding="utf-8") as file:
        for message in messages:
            # Extract only Amharic text from the message
            amharic_message = extract_amharic_text(message)
            
            if amharic_message:  # Only process messages that contain Amharic text
                labeled_tokens = dynamic_label_message(amharic_message)
                for token, label in labeled_tokens:
                    file.write(f"{token}\t{label}\n")
                file.write("\n")  # Blank line to separate messages
    print(f"Labeled dataset saved to {output_file}")

# Main function to run the entire process
if __name__ == "__main__":
    # Read messages from the result.csv
    messages = read_messages_from_csv("result.csv")
    
    # Save the labeled messages in CoNLL format (only Amharic text)
    save_to_conll(messages)
# Out:
# Labeled dataset saved to labeled_dataset.conll
